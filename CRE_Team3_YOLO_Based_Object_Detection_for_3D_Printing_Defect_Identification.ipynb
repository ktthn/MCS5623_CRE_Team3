# %%
# Import necessary libraries
# Import Roboflow library and authenticate
# Access Roboflow project and version

from roboflow import Roboflow

rf = Roboflow(api_key="xvgw0sdWQLrNe21Tpx0e")
project = rf.workspace("abdul-hosog").project("defect-dataset-2")
version = project.version(1)

# Download the dataset in YOLOv11 format
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Defect-Dataset-2-1 in yolov11:: 100%|██████████| 21062/21062 [00:02<00:00, 7552.86it/s]

# %%
# Import and initialize YOLO model for training

from ultralytics import YOLO

model = YOLO('/home/zgalymzha/.local/lib/python3.8/site-packages/ultralytics/cfg/models/11/yolo11.yaml')

# Train the model
model.train(data="/home/zgalymzha/ml_cre/Defect-Dataset-2-1/data.yaml", epochs=20, imgsz=640, batch=16)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.3.36 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81038MiB)
# ...

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/home/zgalymzha/ml_cre/runs/detect/train/confusion_matrix.png', width=600)

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')

model.train(data="/home/zgalymzha/ml_cre/Defect-Dataset-2-1/data.yaml", epochs=100, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.36 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81038MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')

model.train(
    data="/home/zgalymzha/ml_cre/Defect-Dataset-2-1/data.yaml",
    epochs=30,
    batch=64,
    device='0',
    amp=True     # Enabling automatic mixed precision for faster training
)
# Out:
# Ultralytics 8.3.36 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81038MiB)
# ...

# %%
from ultralytics import YOLO
# Loading a different YOLO model (yolov10l) for training

model = YOLO('/home/zgalymzha/.local/lib/python3.8/site-packages/ultralytics/cfg/models/v10/yolov10l.yaml')

model.train(
    data="/home/zgalymzha/ml_cre/Defect-Dataset-2-1/data.yaml",
    epochs=100,
    batch=64,
    device='0,1',
    amp=True
)
# Out:
# Ultralytics 8.3.36 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81038MiB)
#                                                       CUDA:1 (NVIDIA A100 80GB PCIe, 81038MiB)
# ...

# %%
# Display the confusion matrix for the second training run

from IPython.display import Image as IPyImage

IPyImage(filename=f'/home/zgalymzha/ml_cre/runs/detect/train4/confusion_matrix.png', width=600)

# %%
# Display the results plot for the second training run

from IPython.display import Image as IPyImage

IPyImage(filename=f'/home/zgalymzha/ml_cre/runs/detect/train4/results.png', width=600)

# %%
# Display a prediction image from the validation set

from IPython.display import Image as IPyImage

IPyImage(filename=f'./runs/detect/train4/val_batch0_pred.jpg', width=600)

# %%
# Display another prediction image from the validation set

from IPython.display import Image as IPyImage

IPyImage(filename=f'./runs/detect/train4/val_batch2_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=/home/zgalymzha/ml_cre/runs/detect/train4/weights/best.pt data=/home/zgalymzha/ml_cre/Defect-Dataset-2-1/data.yaml
# Out:
# Ultralytics 8.3.36 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81038MiB)
# YOLOv10l summary (fused): 461 layers, 25,720,994 parameters, 0 gradients, 126.3 GFLOPs
# val: Scanning /data1/home/zgalymzha/ml_cre/Defect-Dataset-2-1/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 144, len(boxes) = 1500. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        658       1500      0.625      0.535       0.53      0.369
#              Spaghetti        363        765      0.848      0.757      0.809      0.682
#              Stringing        146        443      0.508      0.388      0.328      0.182
#                Warping        150        292      0.518      0.459      0.454      0.245
# ...

# %%
# Running YOLO in validation mode


# !yolo task=detect mode=predict model=/home/zgalymzha/ml_cre/runs/detect/train4/weights/best.pt conf=0.25 source=/home/zgalymzha/ml_cre/Defect-Dataset-2-1/test/images save=True
# Out:
# Ultralytics 8.3.36 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81038MiB)
# YOLOv10l summary (fused): 461 layers, 25,720,994 parameters, 0 gradients, 126.3 GFLOPs
#
# image 1/657 /home/zgalymzha/ml_cre/Defect-Dataset-2-1/test/images/00019_error_dataset_jpeg.rf.b502842de3d987143ebdbae09b6ac7b9.jpg: 640x640 1 Stringing, 12.2ms
# image 2/657 /home/zgalymzha/ml_cre/Defect-Dataset-2-1/test/images/00038_error_dataset_jpeg.rf.4ea4aa6c0b6373d126f48b7587472942.jpg: 640x640 1 Stringing, 12.9ms
# image 3/657 /home/zgalymzha/ml_cre/Defect-Dataset-2-1/test/images/00046_error_dataset_jpeg.rf.b0eebb99c9f015c29bff105d7fc53d3c.jpg: 640x640 3 Spaghettis, 13.0ms
# image 4/657 /home/zgalymzha/ml_cre/Defect-Dataset-2-1/test/images/00078_error_dataset_jpeg.rf.4be354e3a745e15188ff0e88fa82afa0.jpg: 640x640 3 Spaghettis, 11.4ms
# image 5/657 /home/zgalymzha/ml_cre/Defect-Dataset-2-1/test/images/00127_error_dataset_jpeg.rf.b76bc8f78a1dd3959ba93fb89d172f36.jpg: 640x640 1 Spaghetti, 11.4ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

# Displaying first 5 predited results

latest_folder = max(glob.glob('/home/zgalymzha/ml_cre/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:5]:
    display(IPyImage(filename=img, width=600))
    print("\n")
